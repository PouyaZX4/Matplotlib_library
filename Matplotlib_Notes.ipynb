# %% [markdown]
# # Matplotlib

# %% [markdown]
# for turning the data into visualizations like plots and figures

# %% [markdown]
# + Built on NumPy arrays (and python)
# + integrates directly with pandas
# + can create basic or advance plots
# + simple to use interface (once you get the foundations)

# %% [markdown]
# # Introduction to Matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
plt.plot();

# %%
plt.plot()
plt.show()

# %%
plt.plot([1, 2, 3, 4],[2,4,6,8]);

# %%
x = [1, 2, 3 ,4]
y = [11, 22, 33 ,44]

# %%
plt.plot(x, y);

# %%
# first method
fig = plt.figure() # creats a figure  
ax = fig.add_subplot() # add some axis
plt.show()

# %%
# second method
fig = plt.figure() # creats a figure
ax = fig.add_axes([1, 1, 1, 1])
ax.plot(x,y)
plt.show()

# %%
# 3rd method (recommended)
fig, ax = plt.subplots()
ax.plot(x, [50, 100, 200, 250]); # add some data

# %%
fig, ax = plt.subplots()
ax.plot(x, [50, 100, 200, 250]); 
type(fig), type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._axes.Axes)

# %% [markdown]
# # Matplotlib example Workflow

# %%
# 0. Import matplotlib and get it ready for plotting in Jupyter
# %matplotlib inline
import matplotlib.pyplot as plt

# 1. Prepare data
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

# 2. setup plot
fig, ax = plt.subplots(figsize=(8, 8)) # (Width, height)

# 3. plot data
ax.plot(x, y)

# 4. customize plot
ax.set(title="Simple plot",
       xlabel="x-axis",  # xlabel
       ylabel="y-axis")  # ylabel

# 5. Save & show (you save the figure)
fig.savefig("images_pyplot")

# %% [markdown]
# ##  Making figures with NumPy arrays
# We Want:
# * line plot
# * Scatter plot
# * Bar Plot
# * Histogram
# * Subplot

# %%
import numpy as np

# %%
# Create some data
x = np.linspace(0,10, 100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
# Plot the data and create a line plot
fig, ax = plt.subplots()
ax.plot(x, x**2);

# %%
# Use the same data to make a Scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x));

# %%
# Another scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x));

# %%
# Make a plor from dictionary
nut_butter_prices = {"Almond Butter": 10,
                     "Peanut Butter": 8,
                     "Cashew Butter": 12}
fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax.set(title= "Dan's Nut Butter Store",
       ylabel= "Price ($)",
       xlabel= "Nut Butter");

# %%
fig, ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()), list(nut_butter_prices.values()));
# for making a horizontal bar out of dictionay we need to turn each part into a list

# %%
# Make some data for Histograms and plot it
x = np.random.randn(1000)
fig, ax = plt.subplots()
ax.hist(x);

# %% [markdown]
#  # Two Options for subplots

# %%
# Subplots option 1
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2,
                                             ncols=2,
                                             figsize=(10, 5)) 
# Plot to each different axis
ax1.plot(x, x/2);
ax2.scatter(np.random.random(10), np.random.random(10));
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax4.hist(np.random.randn(1000));
# Costumizing the axis
ax1.set(title="Normal distorbution");
ax3.set(title="Daniels Nut Prices",
        xlabel="Nuts",
        ylabel="Prices ($)");
ax4.set(title="Normal disturbution")
# Making them cleaner in the outview
plt.tight_layout()

# %%
# Subplots Option 2
fig, ax = plt.subplots(nrows=2,
                       ncols=2,
                       figsize=(10, 5))
# Plot to each different index
ax[0, 0].plot(x, x/2);
ax[0, 1].scatter(np.random.random(10), np.random.random(10));
ax[1, 0].bar(nut_butter_prices.keys(),nut_butter_prices.values());
ax[1, 1].hist(np.random.randn(1000));

# %% [markdown]
# ## Plotting from Pandas DataFrames

# %%
import pandas as pd

# %%
# Make a dataframe
car_sales = pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000),
               index=pd.date_range("1/1/2023", periods=1000))
ts = ts.cumsum()
ts.plot();

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# removing the price tags
car_sales["Price"] = car_sales["Price"].str.replace("[\$\,]", "", regex=True).astype(float).astype(int)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Sales Date"] = pd.date_range("1/1/2023", periods=len(car_sales))

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date
# 0  Toyota  White         150043      4   4000 2023-01-01
# 1   Honda    Red          87899      4   5000 2023-01-02
# 2  Toyota   Blue          32549      3   7000 2023-01-03
# 3     BMW  Black          11179      5  22000 2023-01-04
# 4  Nissan  White         213095      4   3500 2023-01-05
# 5  Toyota  Green          99213      4   4500 2023-01-06
# 6   Honda   Blue          45698      4   7500 2023-01-07
# 7   Honda   Blue          54738      4   7000 2023-01-08
# 8  Toyota  White          60000      4   6250 2023-01-09
# 9  Nissan  White          31600      4   9700 2023-01-10

# %%
type(car_sales["Sales Date"][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
car_sales["Total Sales"] = car_sales["Price"].cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date  Total Sales
# 0  Toyota  White         150043      4   4000 2023-01-01         4000
# 1   Honda    Red          87899      4   5000 2023-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2023-01-03        16000
# 3     BMW  Black          11179      5  22000 2023-01-04        38000
# 4  Nissan  White         213095      4   3500 2023-01-05        41500
# 5  Toyota  Green          99213      4   4500 2023-01-06        46000
# 6   Honda   Blue          45698      4   7500 2023-01-07        53500
# 7   Honda   Blue          54738      4   7000 2023-01-08        60500
# 8  Toyota  White          60000      4   6250 2023-01-09        66750
# 9  Nissan  White          31600      4   9700 2023-01-10        76450

# %%
# Let's plot the total sales
car_sales.plot(x="Sales Date", y="Total Sales");

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %%
# How about a bar graph?
x = np.random.rand(10, 4)
x

# turn it into a data frame
df = pd.DataFrame(x, columns=["a", "b", "c", "d"])
df
# Out:
#           a         b         c         d
# 0  0.236879  0.023430  0.554132  0.736842
# 1  0.804476  0.637997  0.414391  0.206470
# 2  0.174820  0.601269  0.038198  0.138834
# 3  0.233736  0.232348  0.847659  0.307167
# 4  0.749568  0.698080  0.978639  0.289804
# 5  0.006316  0.631666  0.119900  0.007409
# 6  0.305444  0.340080  0.293785  0.486650
# 7  0.892593  0.699614  0.280235  0.636186
# 8  0.123725  0.649468  0.234605  0.287574
# 9  0.898419  0.439880  0.458942  0.662168

# %%
df.plot.bar();

# %%
df.plot(kind="bar");

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date  Total Sales
# 0  Toyota  White         150043      4   4000 2023-01-01         4000
# 1   Honda    Red          87899      4   5000 2023-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2023-01-03        16000
# 3     BMW  Black          11179      5  22000 2023-01-04        38000
# 4  Nissan  White         213095      4   3500 2023-01-05        41500
# 5  Toyota  Green          99213      4   4500 2023-01-06        46000
# 6   Honda   Blue          45698      4   7500 2023-01-07        53500
# 7   Honda   Blue          54738      4   7000 2023-01-08        60500
# 8  Toyota  White          60000      4   6250 2023-01-09        66750
# 9  Nissan  White          31600      4   9700 2023-01-10        76450

# %%
car_sales.plot(x="Make", y="Odometer (KM)", kind="bar");

# %%
# How about histograms?

car_sales["Odometer (KM)"].plot.hist();

# %%
car_sales["Odometer (KM)"].plot(kind = "hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
car_sales["Odometer (KM)"].plot.hist(bins=10);

# %%
# Let's Try another dataset
heart_disease = pd.read_csv("92 - heart-disease.csv")
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# Create a histogram of age column
heart_disease["age"].plot.hist(bins=10);

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease.plot.hist(figsize=(10, 30),subplots=True);

# %% [markdown]
# ## Which one should i use? (Pyplot vs matplotlib OO method?)
# * when plotting something quickly, Ok to use puplot method
# * when plotting something advance use OO method

# %%
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
over_50 = heart_disease[heart_disease["age"] > 50]
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# Pyplot method
over_50.plot(kind ="scatter",
             x = "age",
             y="chol",
             c="target",
             figsize=(10,5));    # c is short for colour

# %%
# OO method + Pyplot method
fix , ax = plt.subplots(figsize=(10, 6))
over_50.plot(kind="scatter",
             x= "age",
             y = "chol",
             c = "target",
             ax=ax);
ax.set_xlim([45, 100]);

# %%
# OO method
fig, ax = plt.subplots(figsize=(10, 6))

# plot the data  
scatter = ax.scatter(x=over_50["age"],
                     y =over_50["chol"],
                     c=over_50["target"])

# Customize the plot
ax.set(title="Heart disease and cholesterol Levels",
       xlabel= "Age",
       ylabel= "cholesterol",);

# Add a legend
ax.legend(*scatter.legend_elements(), title="Target");

# Add a horizontal line
ax.axhline(over_50["chol"].mean(),
           linestyle="--");

# %%
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# Subplots of chol, age, thalach
fig, (ax0, ax1) = plt.subplots(figsize=(10,10),
                               nrows=2,
                               ncols=1)
# add data to the ax0
scatter = ax0.scatter(x=over_50["age"],
                      y=over_50["chol"],
                      c=over_50["target"]);
# customize ax0
ax0.set(title="Heart disease and cholesterol levels",
        xlabel="Age",
        ylabel="Cholesterol");
# add a legend to ax0
ax0.legend(*scatter.legend_elements(),
           title="target");
# Add a mean line
ax0.axhline(y=over_50["chol"].mean(),
            linestyle="--");
# add data to ax1
scatter = ax1.scatter(x=over_50["age"],
                     y=over_50["thalach"],
                     c=over_50["target"]);
ax1.set(title="Heart Disease and Max heart Rate",
        xlabel="Age",
        ylabel="Max Heart Rate");
ax1.legend(*scatter.legend_elements(),
           title="thalach");
ax1.axhline(y=over_50["thalach"].mean(),
            linestyle="--");

# Add a title to the figure
fig.suptitle("Heart Disease Analysis",fontsize=16, fontweight="bold")
# Out:
# Text(0.5, 0.98, 'Heart Disease Analysis')

# %% [markdown]
# ## Customizing Matplotlib plots and getting stylish

# %%
# customizing the figures
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales["Price"].plot();

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date  Total Sales
# 0  Toyota  White         150043      4   4000 2023-01-01         4000
# 1   Honda    Red          87899      4   5000 2023-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2023-01-03        16000
# 3     BMW  Black          11179      5  22000 2023-01-04        38000
# 4  Nissan  White         213095      4   3500 2023-01-05        41500

# %%
plt.style.use('seaborn-v0_8-whitegrid')

# %%
car_sales["Price"].plot();

# %%
plt.style.use("seaborn-v0_8")

# %%
car_sales["Price"].plot();

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %%
plt.style.use("ggplot")
car_sales["Price"].plot();

# %%
# Create some data 
x = np.random.randn(10, 4)
x
# Out:
# array([[-0.2467541 , -0.83918064, -2.4661305 ,  0.75072713],
#        [-0.10725095, -0.24041808, -0.32645478, -0.11367135],
#        [-0.01503722, -1.31011397,  1.05048947,  0.31664923],
#        [ 0.71688594, -0.36456296,  0.48989015,  0.93041727],
#        [-0.10761077,  0.36000843, -0.32189843, -0.43561882],
#        [ 0.23713489,  1.21286107, -2.41232522, -2.24426272],
#        [-0.7035988 , -0.42213686,  0.05478878,  0.41665753],
#        [-3.23888217, -1.63096411, -1.00147341, -0.09857779],
#        [-1.73808669, -0.04754377,  1.39127854, -1.41819527],
#        [ 0.45592302,  1.92987935,  0.45397566, -0.81432466]])

# %%
df = pd.DataFrame(x, columns=['a', "b", "c", "d"])
df
# Out:
#           a         b         c         d
# 0 -0.246754 -0.839181 -2.466130  0.750727
# 1 -0.107251 -0.240418 -0.326455 -0.113671
# 2 -0.015037 -1.310114  1.050489  0.316649
# 3  0.716886 -0.364563  0.489890  0.930417
# 4 -0.107611  0.360008 -0.321898 -0.435619
# 5  0.237135  1.212861 -2.412325 -2.244263
# 6 -0.703599 -0.422137  0.054789  0.416658
# 7 -3.238882 -1.630964 -1.001473 -0.098578
# 8 -1.738087 -0.047544  1.391279 -1.418195
# 9  0.455923  1.929879  0.453976 -0.814325

# %%
ax = df.plot(kind="bar");
type(ax)
# Out:
# matplotlib.axes._axes.Axes

# %%
# Customize the plot with the set method
ax = df.plot(kind="bar");
# add some labels and title
ax.set(title="Random Number Bar Graph From Data Frame",
       xlabel="Row number",
       ylabel="Random number");
# making the legend visible:
ax.legend().set_visible(True)

# %%
plt.style.use('seaborn-v0_8')

fig, ax = plt.subplots(figsize=(10,6))
scatter = ax.scatter(x=over_50["age"],
                     y=over_50["chol"],
                     c=over_50["target"],
                     cmap="winter"); # This changes the colour skin
ax.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel="Cholesterol")
# add a legend
ax.legend(*scatter.legend_elements(), title="target");
# horizontal line:
ax.axhline(over_50["chol"].mean(),linestyle="--");

# %% [markdown]
# This plot shows some information about heart disease dataset...

# %%
# Customizing the y and x axis limitations
# Subplots of chol, age, thalach
fig, (ax0, ax1) = plt.subplots(figsize=(10,10),
                               nrows=2,
                               ncols=1)
# add data to the ax0
scatter = ax0.scatter(x=over_50["age"],
                      y=over_50["chol"],
                      c=over_50["target"],
                      cmap="winter");
# customize ax0
ax0.set(title="Heart disease and cholesterol levels",
        ylabel="Cholesterol");
# change the x axis limits 
ax0.set_xlim([50, 80])
# add a legend to ax0
ax0.legend(*scatter.legend_elements(),
           title="target");
# Add a mean line
ax0.axhline(y=over_50["chol"].mean(),
            linestyle="--");
# add data to ax1
scatter = ax1.scatter(x=over_50["age"],
                     y=over_50["thalach"],
                     c=over_50["target"],
                      cmap="winter");
ax1.set(title="Heart Disease and Max heart Rate",
        xlabel="Age",
        ylabel="Max Heart Rate");
ax1.set_xlim([50, 80])
ax1.set_ylim([0,200])
ax1.legend(*scatter.legend_elements(),
           title="thalach");
ax1.axhline(y=over_50["thalach"].mean(),
            linestyle="--");

# Add a title to the figure
fig.suptitle("Heart Disease Analysis",fontsize=16, fontweight="bold")
# Out:
# Text(0.5, 0.98, 'Heart Disease Analysis')

# %%
fig.savefig("Hear_disease-analysis-plot-saved-with-code.png")
